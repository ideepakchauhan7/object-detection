# %% [markdown]
# # Dataset EDA
#
# Explore YOLO-format labels, split sizes, and class distribution.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if str(PROJECT_ROOT / 'src') not in sys.path:
    sys.path.append(str(PROJECT_ROOT / 'src'))

from preprocess import summarize_dataset
from visualize import plot_class_distribution

summary = summarize_dataset('data/dataset.yaml')
summary

# %%
plot_class_distribution('data/dataset.yaml', 'runs/class_distribution.png')
